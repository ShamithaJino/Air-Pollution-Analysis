# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import requests
import geopandas as gpd

# %%
url="https://catalog.data.gov/dataset/tiger-line-shapefile-current-nation-u-s-state-and-equivalent-entities?"

# %%
url = "https://www2.census.gov/geo/tiger/TIGER2025/STATE/tl_2025_us_state.zip"
gdf = gpd.read_file(url)
gdf.head(5)
gdf.info()
# print(gdf.head())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   REGION    56 non-null     object
#  1   DIVISION  56 non-null     object
#  2   STATEFP   56 non-null     object
#  3   STATENS   56 non-null     object
#  4   GEOID     56 non-null     object
#  5   GEOIDFQ   56 non-null     object
#  6   STUSPS    56 non-null     object
#  7   NAME      56 non-null     object
#  8   LSAD      56 non-null     object
#  9   MTFCC     56 non-null     object
#  10  FUNCSTAT  56 non-null     object
#  11  ALAND     56 non-null     int64
#  12  AWATER    56 non-null     int64
#  13  INTPTLAT  56 non-null     object
#  14  INTPTLON  56 non-null     object
#  15  geometry  56 non-null     geometry
# dtypes: geometry(1), int64(2), object(13)
# memory usage: 7.1+ KB

# %%
States_df = gdf[['STUSPS', 'NAME','INTPTLAT', 'INTPTLON', 'geometry']]
States_df.to_csv(r'C:\Users\jinor\OneDrive\Documents\NSS\python\capstone_trial\data\states_boundries_updated.csv', index=False)
